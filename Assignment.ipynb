# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #Que 1. Read superstore data

# %%
import xlrd
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\Hp\Downloads\datasets\datasets\datasets\Superstore.xls')
df.head()
# Out:
#     no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0  NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#create a numpy datetime array
#import numpy as np
#some_dates=np.array(['2016-03-15','2017-05-24','2018-08-09'],dtype='datetime64[D]')
#some_dates

# %%
#conert to an Index
#idx=pd.DatetimeIndex(some_dates)
#idx

# %%
#g=df.set_index('OrderDate',inplace=True)

# %%
#data.set_index('OrderDate').head(6)

# %%
#d=pd.DatetimeIndex(df,idx, OrderDate)

# %% [markdown]
# #QUE 2.find the index of the data

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# #QUE 3.find the columns of the data

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# #QUE 4. if columns name is having space then remove the
# space and rename the column. find the various ways
# to rename the column

# %%
df.columns.str.replace(' ', '')
# Out:
# Index(['no', 'order_id', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'Sub-Category', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.rename(columns=rename_dict)
# Out:
#           no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...      ...             ...        ...        ...           ...         ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States    Henderson  ...       42420
# ...            ...       ...            ...          ...  ...         ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# ...

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# #QUE 5. display first 40 records

# %%
df.head(40)
# Out:
#       no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# #QUE 6. display last 15 records from the data

# %%
df.tail(15)
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# #QUE 7. change the setting to display minimum 30 rows for
# df

# %%
df
# Out:
#           no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...      ...             ...        ...        ...           ...         ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States    Henderson  ...       42420
# ...            ...       ...            ...          ...  ...         ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# ...

# %%
pd.options.display.min_rows=30

# %% [markdown]
# #QUE 8. change the display setting to minimum row as 3

# %%
pd.options.display.min_rows=3

# %%
df
# Out:
#           no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...      ...             ...        ...        ...           ...         ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States    Henderson  ...       42420
# ...            ...       ...            ...          ...  ...         ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# ...

# %% [markdown]
# #QUE 9.take a slice from the dataframe based on the
# columns city, state, region, profit columns

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.loc[:,['City','State','Region','Profit']]
# Out:
#              City       State Region   Profit
# 0       Henderson    Kentucky  South  41.9136
# ...           ...         ...    ...      ...
# 9993  Westminster  California   West  72.9480
#
# [9994 rows x 4 columns]

# %% [markdown]
# #QUE 10. Take a slice based on data available at 1000 to 1500 position and columns from 4 to 8

# %%
df.iloc[1000:1500,4:8]
# Out:
#            Ship Mode Customer ID  Customer Name      Segment
# 1000  Standard Class    FM-14290   Frank Merwin  Home Office
# ...              ...         ...            ...          ...
# 1499  Standard Class    NG-18430  Nathan Gelder     Consumer
#
# [500 rows x 4 columns]

# %% [markdown]
# #QUE 11. Rename the index starts from 1900 to end of the data

# %%
df.index=range(1900,1900+len(df))
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Postal Code  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...       42420
# ...             ...       ...            ...          ...  ...         ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#        Region       Product ID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %% [markdown]
# 12. Take a slice from data based on index having
# name as 1920 , 1940, 1945, 1980, and columns as
# profit, state, category, sub-category, region

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.loc[[1920,1940,1945,1980],['Profit','State','Category','Sub-Category']]
# Out:
#        Profit       State         Category Sub-Category
# 1920   7.3840  California  Office Supplies      Binders
# 1940  41.7564       Texas       Technology       Phones
# 1945   8.2062   Minnesota  Office Supplies      Binders
# 1980   8.0352     Alabama  Office Supplies      Binders

# %% [markdown]
# #QUE 13. Check the data type of columns

# %%
df.dtypes
# Out:
# no                      float64
# order _id                object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# 14. Find out the record for the month of jun-2014

# %%
df[(df['Order Date']>='2014-06-01')&(df['Order Date']<='2014-06-30')]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       Customer ID      Customer Name   Segment        Country         City  \
# 1905     BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# ...           ...                ...       ...            ...          ...
# 11796    JF-15415  Jennifer Ferguson  Consumer  United States      Chicago
#
#        ... Postal Code   Region       Product ID         Category  \
# 1905   ...       90032     West  FUR-FU-10001487        Furniture
# ...    ...         ...      ...              ...              ...
# 11796  ...       60653  Central  OFF-PA-10001725  Office Supplies
#
#       Sub-Category                                       Product Name   Sales  \
# ...

# %%
df[(df['Order Date']>='2014-06-01')&(df['Order Date']<='2014-06-30')].shape
# Out:
# (135, 21)

# %%
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Postal Code  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...       42420
# ...             ...       ...            ...          ...  ...         ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#        Region       Product ID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %%
df.describe(include='all')
# Out:
#                  no       order _id                     Order Date  \
# count   9993.000000            9993                           9994
# unique          NaN            5009                            NaN
# top             NaN  CA-2017-100111                            NaN
# freq            NaN              14                            NaN
# mean    4998.000000             NaN  2016-04-30 00:07:12.259355648
# min        2.000000             NaN            2014-01-03 00:00:00
# 25%     2500.000000             NaN            2015-05-23 00:00:00
# 50%     4998.000000             NaN            2016-06-26 00:00:00
# 75%     7496.000000             NaN            2017-05-14 00:00:00
# max     9994.000000             NaN            2017-12-30 00:00:00
# std     2884.874954             NaN                            NaN
#
#                             Ship Date       Ship Mode Customer ID  \
# count                            9994            9994        9994
# ...

# %% [markdown]
# #QUE 15. Calculate month wise average of profit.

# %%
df.dtypes
# Out:
# no                      float64
# order _id                object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Month']=df['Order Date'].dt.month
df['Month']
# Out:
# 1900     11
#          ..
# 11893     5
# Name: Month, Length: 9994, dtype: int32

# %%
month_wise_avg_profit=df.groupby(df['Month'])['Profit'].mean()
month_wise_avg_profit
# Out:
# Month
# 1     23.974924
# 2     34.315369
# 3     41.084321
# 4     17.346462
# 5     30.491575
# 6     29.687302
# 7     19.482626
# 8     30.845522
# 9     26.650380
# 10    38.808353
# 11    24.111779
# 12    30.801983
# Name: Profit, dtype: float64

# %%
#df.groupby('Order Date')['Profit'].mean()

# %%
#month_wise_avg_profit = df.groupby(df['Month'])['Profit'].mean()

# %%
#creation of dynamic variable for last question

# %% [markdown]
# #QUE 16. Create the new data frame for California

# %% [markdown]
# df=pd.DatetimeIndex(d,idx,A)

# %%
df.resample(rule='A').mean(['Profit','Sales'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7924\938695221.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.resample(rule='A').mean(['Profit','Sales'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df.resample(rule='A').mean(['Profit','Sales'])
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:9771, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9768 else:
#    9769     convention = "start"
# -> 9771 return get_resampler(
#    9772     cast("Series | DataFrame", self),
#    9773     freq=rule,
#    9774     label=label,
#    9775     closed=closed,
#    9776     axis=axis,
#    9777     kind=kind,
#    9778     convention=convention,
#    9779     key=on,
# ...

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
result=df[df['State']=='California']

# %%
result
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#          Customer Name    Segment        Country         City  ... Region  \
# 1902   Darrin Van Huff  Corporate  United States  Los Angeles  ...   West
# ...                ...        ...            ...          ...  ...    ...
# 11893     Chris Cortes   Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1902   OFF-LA-10000240  Office Supplies       Labels
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# ...

# %%
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Region  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...  South
# ...             ...       ...            ...          ...  ...    ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1900   FUR-BO-10001798        Furniture    Bookcases
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# 1900                   Bush Somerset Collection Bookcase  261.96        2
# ...

# %% [markdown]
# #QUE 17. Find sum of sales

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603000003)

# %% [markdown]
# #QUE 18 18. Find state wise sum of sales.

# %%
df.groupby('State')['Sales'].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %% [markdown]
# #QUE 19. Find month wise sum of sales

# %%
import pandas as pd

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Month']=df['Order Date'].dt.month
df['Month']
# Out:
# 1900     11
#          ..
# 11893     5
# Name: Month, Length: 9994, dtype: int32

# %%
df.groupby('Month')['Sales'].sum()
# Out:
# Month
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %% [markdown]
# #QUE 20. Find country wise and city wise average profit

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Month'],
#       dtype='object')

# %%
df.groupby(['Country','City'])['Profit'].mean()
#con2=df.groupby(df['City'])['Profit'].mean()
# Out:
# Country        City
# United States  Aberdeen      6.630000
#                               ...
#                Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %% [markdown]
# #QUE 21. Calculate region wise average profit.

# %%
df.groupby(['Region'])['Profit'].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# #QUe 22. Find the ship mode which is more profitable.

# %%
df.groupby('Ship Mode')['Profit'].sum().reset_index()
# Out:
#         Ship Mode       Profit
# 0     First Class   48969.8399
# 1        Same Day   15891.7589
# 2    Second Class   57446.6354
# 3  Standard Class  164088.7875

# %%
df.groupby('Ship Mode')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)
# Out:
#         Ship Mode       Profit
# 3  Standard Class  164088.7875
# 2    Second Class   57446.6354
# 0     First Class   48969.8399
# 1        Same Day   15891.7589

# %% [markdown]
# #QUE 23. Create a new data frame where loss is recorded

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Month'],
#       dtype='object')

# %%
loss=df[df['Profit']<0]
loss
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       Customer ID     Customer Name      Segment        Country  \
# 1903     SO-20335    Sean O'Donnell     Consumer  United States
# ...           ...               ...          ...            ...
# 11862    CM-12655  Corinna Mitchell  Home Office  United States
#
#                   City  ...   Region       Product ID   Category Sub-Category  \
# 1903   Fort Lauderdale  ...    South  FUR-TA-10000577  Furniture       Tables
# ...                ...  ...      ...              ...        ...          ...
# 11862          Houston  ...  Central  FUR-BO-10004218  Furniture    Bookcases
#
#                                             Product Name     Sales Quantity  \
# ...

# %% [markdown]
# #QUE 24. Find category wise sub category wise sales

# %%
df.groupby(['Category','Sub-Category'])['Sales'].sum().reset_index()
# Out:
#            Category Sub-Category        Sales
# 0         Furniture    Bookcases  114879.9963
# 1         Furniture       Chairs  328449.1030
# 2         Furniture  Furnishings   91705.1640
# 3         Furniture       Tables  206965.5320
# 4   Office Supplies   Appliances  107532.1610
# 5   Office Supplies          Art   27118.7920
# 6   Office Supplies      Binders  203412.7330
# 7   Office Supplies    Envelopes   16476.4020
# 8   Office Supplies    Fasteners    3024.2800
# 9   Office Supplies       Labels   12486.3120
# 10  Office Supplies        Paper   78479.2060
# 11  Office Supplies      Storage  223843.6080
# 12  Office Supplies     Supplies   46673.5380
# 13       Technology  Accessories  167380.3180
# 14       Technology      Copiers  149528.0300
# 15       Technology     Machines  189238.6310
# 16       Technology       Phones  330007.0540

# %%
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Region  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...  South
# ...             ...       ...            ...          ...  ...    ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1900   FUR-BO-10001798        Furniture    Bookcases
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# 1900                   Bush Somerset Collection Bookcase  261.96        2
# ...

# %% [markdown]
# #QUE 25. Create a data frame for record where discount is 0

# %%
df.shape
# Out:
# (9994, 22)

# %%
df[df['Discount']==0]
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Region  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...  South
# ...             ...       ...            ...          ...  ...    ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1900   FUR-BO-10001798        Furniture    Bookcases
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# 1900                   Bush Somerset Collection Bookcase  261.96        2
# ...

# %% [markdown]
# #QUE 26 Create a data frame where order date and ship date both are in JAN-2014

# %%
cond1=(df['Order Date']>='2014-06-01')&(df['Order Date']<='2014-06-30')

cond2=(df['Ship Date']>='2014-06-01')&(df['Ship Date']<='2014-06-30')
df[cond1 & cond2]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       Customer ID      Customer Name   Segment        Country         City  \
# 1905     BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# ...           ...                ...       ...            ...          ...
# 11796    JF-15415  Jennifer Ferguson  Consumer  United States      Chicago
#
#        ... Postal Code   Region       Product ID         Category  \
# 1905   ...       90032     West  FUR-FU-10001487        Furniture
# ...    ...         ...      ...              ...              ...
# 11796  ...       60653  Central  OFF-PA-10001725  Office Supplies
#
#       Sub-Category                                       Product Name   Sales  \
# ...

# %% [markdown]
# #QUE 27 Find records having profit for consumer segment.

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns
df.groupby('Segment')['Profit']
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Postal Code  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...       42420
# ...             ...       ...            ...          ...  ...         ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#        Region       Product ID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %% [markdown]
# #Que 28 Generate new data frame for every state (hint: dynamic variable creation)

# %%
new_dataset_state=df["State"].unique()
new_dataset_state
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
s_df={state:df[df["State"]==state]for state in new_dataset_state}
s_df
# Out:
# {'Kentucky':            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
#  1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
#  ...       ...             ...        ...        ...           ...         ...
#  11860  9961.0  CA-2017-141446 2017-09-16 2017-09-18  Second Class    CL-12700
#
#        Customer Name      Segment        Country       City  ... Postal Code  \
#  1900    Claire Gute     Consumer  United States  Henderson  ...       42420
#  ...             ...          ...            ...        ...  ...         ...
#  11860  Craig Leslie  Home Office  United States   Florence  ...       41042
#
#         Region       Product ID    Category Sub-Category  \
#  1900    South  FUR-BO-10001798   Furniture    Bookcases
#  ...       ...              ...         ...          ...
#  11860   South  TEC-AC-10002305  Technology  Accessories
#
#                                  Product Name   Sales  Quantity  Discount  \
# ...

# %% [markdown]
# #QUE 29 Generate the region wise, state wise average profit and sales and then extract information for east region.

# %%
V=df.groupby(['Region','State'])[['Profit','Sales']].mean()
V
# Out:
#                                   Profit        Sales
# Region  State
# Central Illinois              -25.625787   162.939230
#         Indiana               123.375411   359.431946
#         Iowa                   39.460397   152.658667
#         Kansas                 34.851813   121.429583
#         Michigan               95.934069   299.096525
#         Minnesota             121.608847   335.541011
#         Missouri               97.518341   336.441667
#         Nebraska               53.607742   196.445526
#         North Dakota           32.878529   131.415714
#         Oklahoma               73.544788   298.233182
#         South Dakota           32.902358   109.630000
#         Texas                 -26.121174   172.779742
#         Wisconsin              76.380004   291.951000
# East    Connecticut            42.823071   163.223866
#         Delaware              103.930988   285.948635
#         District of Columbia  105.958930   286.502000
# ...

# %%
s=V.reset_index()

# %%
s[s["Region"]=="East"]
# Out:
#    Region                 State      Profit       Sales
# 13   East           Connecticut   42.823071  163.223866
# 14   East              Delaware  103.930988  285.948635
# 15   East  District of Columbia  105.958930  286.502000
# 16   East                 Maine   56.810775  158.816250
# 17   East              Maryland   66.963608  225.766886
# 18   East         Massachusetts   50.262975  212.106919
# 19   East         New Hampshire   63.203807  270.093481
# 20   East            New Jersey   75.176260  275.110092
# 21   East              New York   65.637011  275.599531
# 22   East                  Ohio  -36.186304  166.861697
# 23   East          Pennsylvania  -26.507598  198.487077
# 24   East          Rhode Island  130.100523  404.070643
# 25   East               Vermont  204.088936  811.760909
# 26   East         West Virginia   46.480400  302.456000

# %% [markdown]
# #QUE 30  Find all record for furniture delivered in Texas

# %%
df[(df['State']=='Texas')&(df['Category']=="Furniture")]
# Out:
#            no       order _id Order Date  Ship Date    Ship Mode Customer ID  \
# 1936     37.0  CA-2016-117590 2016-12-08 2016-12-10  First Class    GH-14485
# ...       ...             ...        ...        ...          ...         ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22  First Class    CM-12655
#
#           Customer Name      Segment        Country        City  ...  \
# 1936          Gene Hale    Corporate  United States  Richardson  ...
# ...                 ...          ...            ...         ...  ...
# 11862  Corinna Mitchell  Home Office  United States     Houston  ...
#
#       Postal Code   Region       Product ID   Category Sub-Category  \
# 1936        75080  Central  FUR-FU-10003664  Furniture  Furnishings
# ...           ...      ...              ...        ...          ...
# 11862       77041  Central  FUR-BO-10004218  Furniture    Bookcases
#
#                                             Product Name     Sales  Quantity  \
# ...
